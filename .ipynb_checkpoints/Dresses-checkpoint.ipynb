# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

data = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = data.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images / 255.0
test_images = test_images / 255.0

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),    #input layer -> image dimensions
    keras.layers.Dense(128, activation="relu"),  #hidden layer size, activation rule (in this case evey node connects to every other on the next layer)
    keras.layers.Dense(10, activation="softmax")  #output layer, softmax means that the sum of all the nodes in this layer makes 1
])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",  #loss function -> result mapped in R num values
              metrics=["accuracy"])

#training
model.fit(train_images, train_labels, epochs=5)      #epochs -> how many times you see the same image

'''
#testing
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Tested acc: ", test_acc)
'''

prediction = model.predict(test_images)

for i in range(5):
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel("Actual: " + class_names[test_labels[i]])
    plt.title("Prediction" + class_names[np.argmax(prediction[i])])
    plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 837us/step - loss: 0.6336 - accuracy: 0.7779
# Epoch 2/5
# 1875/1875 [==============================] - 2s 960us/step - loss: 0.3847 - accuracy: 0.8627
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3384 - accuracy: 0.8751
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3100 - accuracy: 0.8870
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2974 - accuracy: 0.8899
